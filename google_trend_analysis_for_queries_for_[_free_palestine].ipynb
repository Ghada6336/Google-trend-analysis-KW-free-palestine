# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghada6336/Google-trend-analysis-KW-free-palestine/blob/main/google_trend_analysis_for_queries_for_%5B_free_palestine%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Google Search Analysis

# %%
import pandas as pd
# !pip install pytrends
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %% [markdown]
# use trend word [free palestine ]

# %%
trends.build_payload(kw_list=["free palestine"])
data = trends.interest_by_region()
data = data.sort_values(by="free palestine", ascending=False)
data = data.head(15)
print(data)
# Out:
#                       free palestine
# geoName
# Maldives                         100
# Brunei                            47
# Palestine                         36
# Malaysia                          28
# Tunisia                           23
# Qatar                             23
# Jordan                            21
# Pakistan                          20
# Oman                              17
# Morocco                           17
# Bahrain                           16
# United Arab Emirates              15
# Lebanon                           14
# Kuwait                            14
# Bangladesh                        14

# %%
data.reset_index().plot(x="geoName",
                        y="free palestine",
                        figsize=(15, 12), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['free palestine'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['free palestine'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for free palestine ',
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
